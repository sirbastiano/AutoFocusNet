# %%
from SRC import l0decoder

# %%
filepath = '/Users/robertodelprete/Desktop/AutoFocusNet/Data/DATA/S1A_S3_RAW__0SDH_20240524T213606_20240524T213631_054018_069139_241A.SAFE/s1a-s3-raw-s-hh-20240524t213606-20240524t213631-054018-069139.dat'

metadecoder = l0decoder.Level0Decoder(filename=filepath)

metadecoder.decode_metadata()
# Out:
#        Packet Version Number  Packet Type  Secondary Header Flag  PID  PCAT  \
# 0                          0            0                      1   65    12
# 1                          0            0                      1   65    12
# 2                          0            0                      1   65    12
# 3                          0            0                      1   65    12
# 4                          0            0                      1   65    12
# ...                      ...          ...                    ...  ...   ...
# 48936                      0            0                      1   65    12
# 48937                      0            0                      1   65    12
# 48938                      0            0                      1   65    12
# 48939                      0            0                      1   65    12
# 48940                      0            0                      1   65    12
#
# ...
